# %% [markdown]
# Welcome to my final project.  We'll be looking at the Board Game Geek database in order to look at what makes a successful board game.  With several sections of data, ranging from number of players, to average hours for a play, to mechanics and genre.  While I'm coming into this with a good idea of what seems to be a good game (I'm expecting 2-3 hours, 2-3 points of complexity, and an average of around 4 players (party games and 2 player games I expect to have their own constituencies and to roughly even out)  It's also worth noting that BGG is likely to have it's own biases.  But for a student project, it should make for an amazing source of data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
game_df = pd.read_csv(r'C:\Users\Tylor\Documents\GitHub\Learning Projects\Final Project\BGG_Data_Set.csv')
print(game_df.head(20))
print(game_df.describe(include='all'))
print(game_df.info())
# Out:
#           ID                                           Name  Year Published  \
# 0   174430.0                                     Gloomhaven          2017.0
# 1   161936.0                      Pandemic Legacy: Season 1          2015.0
# 2   224517.0                              Brass: Birmingham          2018.0
# 3   167791.0                              Terraforming Mars          2016.0
# 4   233078.0              Twilight Imperium: Fourth Edition          2017.0
# 5   291457.0                   Gloomhaven: Jaws of the Lion          2020.0
# 6   182028.0  Through the Ages: A New Story of Civilization          2015.0
# 7   220308.0                                   Gaia Project          2017.0
# 8   187645.0                           Star Wars: Rebellion          2016.0
# 9    12333.0                              Twilight Struggle          2005.0
# 10  193738.0                            Great Western Trail          2016.0
# 11  115746.0                War of the Ring: Second Edition          2012.0
# 12  162886.0                                  Spirit Island          2017.0
# 13  169786.0                                         Scythe          2016.0
# 14   84876.0                        The Castles of Burgundy          2011.0
# 15  120677.0                                  Terra Mystica          2012.0
# 16  173346.0                                 7 Wonders Duel          2015.0
# 17  124361.0                                      Concordia          2013.0
# 18   28720.0                              Brass: Lancashire          2007.0
# 19  266192.0                                       Wingspan          2019.0
#
#     Min Players  Max Players  Play Time  Min Age  Users Rated  Rating Average  \
# 0             1            4        120       14        42055            8.79
# 1             2            4         60       13        41643            8.61
# 2             2            4        120       14        19217            8.66
# 3             1            5        120       12        64864            8.43
# 4             3            6        480       14        13468            8.70
# 5             1            4        120       14         8392            8.87
# 6             2            4        120       14        23061            8.43
# 7             1            4        150       12        16352            8.49
# 8             2            4        240       14        23081            8.42
# 9             2            2        180       13        40814            8.29
# 10            2            4        150       12        29457            8.30
# 11            2            4        180       13        13725            8.49
# 12            1            4        120       13        25722            8.35
# 13            1            5        115       14        57871            8.24
# 14            2            4         90       12        46507            8.13
# 15            2            5        150       12        39284            8.14
# 16            2            2         30       10        60302            8.11
# 17            2            5        100       13        28105            8.12
# 18            2            4        120       14        19400            8.17
# 19            1            5         70       10        43165            8.11
#
#     BGG Rank  Complexity Average  Owned Users  \
# 0          1                3.86      68323.0
# 1          2                2.84      65294.0
# 2          3                3.91      28785.0
# 3          4                3.24      87099.0
# 4          5                4.22      16831.0
# 5          6                3.55      21609.0
# 6          7                4.41      26985.0
# 7          8                4.35      20312.0
# 8          9                3.71      34849.0
# 9         10                3.59      56219.0
# 10        11                3.71      35804.0
# 11        12                4.14      22281.0
# 12        13                4.01      38254.0
# 13        14                3.41      75640.0
# 14        15                3.00      63058.0
# 15        16                3.96      42720.0
# 16        17                2.23      94343.0
# 17        18                3.03      32014.0
# 18        19                3.86      25429.0
# 19        20                2.42      61775.0
#
#                                             Mechanics  \
# 0   Action Queue, Action Retrieval, Campaign / Bat...
# 1   Action Points, Cooperative Game, Hand Manageme...
# 2   Hand Management, Income, Loans, Market, Networ...
# 3   Card Drafting, Drafting, End Game Bonuses, Han...
# 4   Action Drafting, Area Majority / Influence, Ar...
# 5   Action Queue, Campaign / Battle Card Driven, C...
# 6   Action Points, Auction/Bidding, Auction: Dutch...
# 7   End Game Bonuses, Hexagon Grid, Income, Modula...
# 8   Area Majority / Influence, Area Movement, Area...
# 9   Action/Event, Advantage Token, Area Majority /...
# 10  Deck Bag and Pool Building, Hand Management, O...
# 11  Area Majority / Influence, Area Movement, Camp...
# 12  Action Retrieval, Area Majority / Influence, C...
# 13  Area Majority / Influence, Card Play Conflict ...
# 14  Dice Rolling, Grid Coverage, Hexagon Grid, Set...
# 15  End Game Bonuses, Hexagon Grid, Income, Increa...
# 16  Card Drafting, Drafting, Set Collection, Sudde...
# 17  Action Retrieval, Advantage Token, Auction: Du...
# 18  Hand Management, Income, Loans, Network and Ro...
# 19  Card Drafting, Dice Rolling, Drafting, End Gam...
#
#                            Domains
# 0   Strategy Games, Thematic Games
# 1   Strategy Games, Thematic Games
# 2                   Strategy Games
# 3                   Strategy Games
# 4   Strategy Games, Thematic Games
# 5   Strategy Games, Thematic Games
# 6                   Strategy Games
# 7                   Strategy Games
# 8                   Thematic Games
# 9         Strategy Games, Wargames
# 10                  Strategy Games
# 11        Thematic Games, Wargames
# 12                  Strategy Games
# 13                  Strategy Games
# 14                  Strategy Games
# 15                  Strategy Games
# 16                  Strategy Games
# 17                  Strategy Games
# 18                  Strategy Games
# 19    Family Games, Strategy Games
#                    ID        Name  Year Published   Min Players   Max Players  \
# count    20327.000000       20343    20342.000000  20343.000000  20343.000000
# unique            NaN       19976             NaN           NaN           NaN
# top               NaN  Robin Hood             NaN           NaN           NaN
# freq              NaN           6             NaN           NaN           NaN
# mean    108216.245142         NaN     1984.249877      2.019712      5.672221
# std      98682.097298         NaN      214.003181      0.690366     15.231376
# min          1.000000         NaN    -3500.000000      0.000000      0.000000
# 25%      11029.000000         NaN     2001.000000      2.000000      4.000000
# 50%      88931.000000         NaN     2011.000000      2.000000      4.000000
# 75%     192939.500000         NaN     2016.000000      2.000000      6.000000
# max     331787.000000         NaN     2022.000000     10.000000    999.000000
#
#            Play Time       Min Age    Users Rated  Rating Average  \
# count   20343.000000  20343.000000   20343.000000    20343.000000
# unique           NaN           NaN            NaN             NaN
# top              NaN           NaN            NaN             NaN
# freq             NaN           NaN            NaN             NaN
# mean       91.294548      9.601485     840.971391        6.403227
# std       545.447203      3.645458    3511.562220        0.935911
# min         0.000000      0.000000      30.000000        1.050000
# 25%        30.000000      8.000000      55.000000        5.820000
# 50%        45.000000     10.000000     120.000000        6.430000
# 75%        90.000000     12.000000     385.000000        7.030000
# max     60000.000000     25.000000  102214.000000        9.580000
#
#             BGG Rank  Complexity Average    Owned Users        Mechanics  \
# count   20343.000000        20343.000000   20320.000000            18745
# unique           NaN                 NaN            NaN             7381
# top              NaN                 NaN            NaN  Hand Management
# freq             NaN                 NaN            NaN              432
# mean    10172.890429            1.991188    1408.457628              NaN
# std      5872.831597            0.848903    5040.179315              NaN
# min         1.000000            0.000000       0.000000              NaN
# 25%      5087.500000            1.330000     146.000000              NaN
# 50%     10173.000000            1.970000     309.000000              NaN
# 75%     15258.500000            2.540000     864.000000              NaN
# max     20344.000000            5.000000  155312.000000              NaN
#
#          Domains
# count      10184
# unique        39
# top     Wargames
# freq        3029
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  20327 non-null  float64
#  1   Name                20343 non-null  object
#  2   Year Published      20342 non-null  float64
#  3   Min Players         20343 non-null  int64
#  4   Max Players         20343 non-null  int64
#  5   Play Time           20343 non-null  int64
#  6   Min Age             20343 non-null  int64
#  7   Users Rated         20343 non-null  int64
#  8   Rating Average      20343 non-null  float64
#  9   BGG Rank            20343 non-null  int64
#  10  Complexity Average  20343 non-null  float64
#  11  Owned Users         20320 non-null  float64
#  12  Mechanics           18745 non-null  object
#  13  Domains             10184 non-null  object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 2.2+ MB
# None

# %%
plt.hist(game_df[game_df['Owned Users']<500]['Owned Users'], bins=50)
plt.show()

plt.hist(game_df[game_df['Users Rated']<500]['Users Rated'], bins=50)
plt.show()

print(game_df[game_df['Owned Users'].isnull() == True])
# Out:
#              ID                                               Name  \
# 2828   202755.0                      Guildhall Fantasy: Fellowship
# 3590   196305.0                        Guildhall Fantasy: Alliance
# 3739   196306.0                       Guildhall Fantasy: Coalition
# 5807      289.0                                      Chariot Lords
# 9202     6813.0        Operation Market Garden: Descent into Hell
# 9317      139.0                                               Hoax
# 10075  266756.0              Devil Boats: PT Boats in the Solomons
# 10776       NaN                            Ace of Aces: Jet Eagles
# 10835       NaN                                 Die Erben von Hoax
# 11152       NaN  Rommel in North Africa: The War in the Desert ...
# 11669       NaN                  Migration: A Story of Generations
# 12649       NaN                   Die Insel der steinernen Wachter
# 12764       NaN                   Dragon Ball Z TCG (2014 edition)
# 13282       NaN                                           Dwarfest
# 13984       NaN                                                Hus
# 14053       NaN                                        Contrario 2
# 14663       NaN                           Warage: Extended Edition
# 16292       NaN                                            Rainbow
# 17009       NaN                Sexy, el juego del arte del flirteo
# 18672       NaN                    Dracarys Dice Don't Get Burned!
# 19332       NaN  Battleship: Tactical Capital Ship Combat 1925-...
# 19474       NaN                          The Umbrella Academy Game
# 20040       NaN                                    Hidden Conflict
#
#        Year Published  Min Players  Max Players  Play Time  Min Age  \
# 2828           2016.0            2            4         45       10
# 3590           2016.0            2            4         45       10
# 3739           2016.0            2            4         45       10
# 5807           1999.0            3            4        360       12
# 9202           1985.0            2            2        120       12
# 9317           1981.0            3           12         45       10
# 10075          2021.0            1            1         60       14
# 10776          1990.0            2            2         20       10
# 10835          1999.0            3            8         45       12
# 11152          1986.0            2            2          0       12
# 11669          2012.0            2            4         30       12
# 12649          2009.0            2            4        120       12
# 12764          2014.0            2            2         20        8
# 13282          2014.0            2            6         45       12
# 13984             NaN            2            2         40        0
# 14053          2006.0            2           12          0       14
# 14663          2017.0            2            6         90       10
# 16292          2010.0            2            6         20        8
# 17009          2014.0            3            4        120       18
# 18672          2018.0            2            5         15       10
# 19332          1986.0            2            2         90        8
# 19474          2020.0            1            6         40       12
# 20040          2005.0            2            6         30       10
#
#        Users Rated  Rating Average  BGG Rank  Complexity Average  Owned Users  \
# 2828           565            7.13      2830                2.00          NaN
# 3590           360            7.20      3592                2.14          NaN
# 3739           336            7.19      3741                2.13          NaN
# 5807           221            6.68      5809                3.00          NaN
# 9202            94            6.72      9204                3.00          NaN
# 9317           216            5.97      9319                1.38          NaN
# 10075           49            7.84     10077                2.83          NaN
# 10776          110            6.26     10778                2.00          NaN
# 10835          137            6.05     10837                2.00          NaN
# 11152           53            6.76     11154                4.00          NaN
# 11669           49            7.20     11671                2.00          NaN
# 12649           49            6.73     12651                3.00          NaN
# 12764           33            7.03     12766                2.50          NaN
# 13282           82            6.13     13284                1.75          NaN
# 13984           38            6.28     13986                2.00          NaN
# 14053           37            6.30     14055                1.00          NaN
# 14663           49            7.64     14665                3.00          NaN
# 16292           35            5.65     16294                2.00          NaN
# 17009           39            5.83     17011                2.00          NaN
# 18672           86            5.33     18674                1.00          NaN
# 19332          131            5.07     19334                2.00          NaN
# 19474           41            3.16     19476                1.00          NaN
# 20040          128            4.35     20042                2.00          NaN
#
#                                                Mechanics Domains
# 2828          Hand Management, Take That, Set Collection     NaN
# 3590          Hand Management, Set Collection, Take That     NaN
# 3739          Hand Management, Set Collection, Take That     NaN
# 5807               Area Movement, Variable Player Powers     NaN
# 9202   Dice Rolling, Events, Grid Movement, Hexagon G...     NaN
# 9317                     Deduction, Hidden Roles, Voting     NaN
# 10075                                                NaN     NaN
# 10776                                                NaN     NaN
# 10835                                                NaN     NaN
# 11152                                                NaN     NaN
# 11669                                                NaN     NaN
# 12649                                                NaN     NaN
# 12764                                                NaN     NaN
# 13282                                                NaN     NaN
# 13984                                                NaN     NaN
# 14053                                                NaN     NaN
# 14663                                                NaN     NaN
# 16292                                                NaN     NaN
# 17009                                                NaN     NaN
# 18672                                                NaN     NaN
# 19332                                                NaN     NaN
# 19474                                                NaN     NaN
# 20040                                                NaN     NaN

# %% [markdown]
# Alright, we've got our dataframe setup and we've poked around with it all a little bit.  Now let's wrangle this into useable form.  First up, we'll drop the nulls from Owners and ID.  Since every missing ID also has null ownership, this will be easy to do.  There are two other categories that are missing, but Domains and Game Mechanics will be dealt with in the rest of this process.
#
# Specifically, we'll break those columns up with each possible entry getting their own column with 1/0 results.
#
# Looking into it further, found a method that does everything I want in a single line of code.  Yay?
# The result is a little too big and unwieldy.  Might need to prune it down a bit.

# %%
#Dropping nulls from Owned Users, ID and Year Published.
games = game_df
games = games.dropna(subset=['Owned Users'])

#Now let's split up the domain and mechanic categories and make our mega db.
games = pd.concat([games, games['Domains'].str.get_dummies(sep=', ')], 1)
games = pd.concat([games, games['Mechanics'].str.get_dummies(sep=', ')], 1)
games=games.drop(columns=['Domains', 'Mechanics'])

# %%
#Grabbing a list I can use for subsetting the megadf
domains_df = game_df[['ID', 'Domains']]
domains_df = pd.concat([domains_df, domains_df['Domains'].str.get_dummies(sep=', ')], 1)
domains_df = domains_df.drop(columns=['ID', 'Domains'])
domains = domains_df.columns.values.tolist()
mechanics_df = game_df[['ID', 'Mechanics']]
mechanics_df = pd.concat([mechanics_df, mechanics_df['Mechanics'].str.get_dummies(sep=', ')], 1)
mechanics_df = mechanics_df.drop(columns=['ID', 'Mechanics'])
mechanics = mechanics_df.columns.values.tolist()

# %%
games_columns = games.columns.values.tolist()
print(games_columns)
print(len(games_columns))
print(domains)
print(len(domains))
print(mechanics)
print(len(mechanics))
# Out:
# ['ID', 'Name', 'Year Published', 'Min Players', 'Max Players', 'Play Time', 'Min Age', 'Users Rated', 'Rating Average', 'BGG Rank', 'Complexity Average', 'Owned Users', 'Abstract Games', "Children's Games", 'Customizable Games', 'Family Games', 'Party Games', 'Strategy Games', 'Thematic Games', 'Wargames', 'Acting', 'Action Drafting', 'Action Points', 'Action Queue', 'Action Retrieval', 'Action Timer', 'Action/Event', 'Advantage Token', 'Alliances', 'Area Majority / Influence', 'Area Movement', 'Area-Impulse', 'Auction/Bidding', 'Auction: Dexterity', 'Auction: Dutch', 'Auction: Dutch Priority', 'Auction: English', 'Auction: Fixed Placement', 'Auction: Once Around', 'Auction: Sealed Bid', 'Auction: Turn Order Until Pass', 'Automatic Resource Growth', 'Betting and Bluffing', 'Bias', 'Bingo', 'Bribery', 'Campaign / Battle Card Driven', 'Card Drafting', 'Card Play Conflict Resolution', 'Catch the Leader', 'Chaining', 'Chit-Pull System', 'Closed Economy Auction', 'Command Cards', 'Commodity Speculation', 'Communication Limits', 'Connections', 'Constrained Bidding', 'Contracts', 'Cooperative Game', 'Crayon Rail System', 'Critical Hits and Failures', 'Cube Tower', 'Deck Bag and Pool Building', 'Deck Construction', 'Deduction', 'Delayed Purchase', 'Dice Rolling', 'Die Icon Resolution', 'Different Dice Movement', 'Different Worker Types', 'Drafting', 'Elapsed Real Time Ending', 'Enclosure', 'End Game Bonuses', 'Events', 'Finale Ending', 'Flicking', 'Follow', 'Force Commitment', 'Grid Coverage', 'Grid Movement', 'Hand Management', 'Hexagon Grid', 'Hidden Movement', 'Hidden Roles', 'Hidden Victory Points', 'Highest-Lowest Scoring', 'Hot Potato', 'I Cut You Choose', 'Impulse Movement', 'Income', 'Increase Value of Unchosen Resources', 'Induction', 'Interrupts', 'Investment', 'Kill Steal', 'King of the Hill', 'Ladder Climbing', 'Layering', 'Legacy Game', 'Line Drawing', 'Line of Sight', 'Loans', 'Lose a Turn', 'Mancala', 'Map Addition', 'Map Deformation', 'Map Reduction', 'Market', 'Matching', 'Measurement Movement', 'Melding and Splaying', 'Memory', 'Minimap Resolution', 'Modular Board', 'Move Through Deck', 'Movement Points', 'Movement Template', 'Moving Multiple Units', 'Multiple Maps', 'Multiple-Lot Auction', 'Narrative Choice / Paragraph', 'Negotiation', 'Network and Route Building', 'Once-Per-Game Abilities', 'Order Counters', 'Ownership', 'Paper-and-Pencil', 'Passed Action Token', 'Pattern Building', 'Pattern Movement', 'Pattern Recognition', 'Physical Removal', 'Pick-up and Deliver', 'Pieces as Map', 'Player Elimination', 'Player Judge', 'Point to Point Movement', 'Predictive Bid', "Prisoner's Dilemma", 'Programmed Movement', 'Push Your Luck', 'Race', 'Random Production', 'Ratio / Combat Results Table', 'Re-rolling and Locking', 'Real-Time', 'Relative Movement', 'Resource to Move', 'Rock-Paper-Scissors', 'Role Playing', 'Roles with Asymmetric Information', 'Roll / Spin and Move', 'Rondel', 'Scenario / Mission / Campaign Game', 'Score-and-Reset Game', 'Secret Unit Deployment', 'Selection Order Bid', 'Semi-Cooperative Game', 'Set Collection', 'Simulation', 'Simultaneous Action Selection', 'Singing', 'Single Loser Game', 'Slide/Push', 'Solo / Solitaire Game', 'Speed Matching', 'Square Grid', 'Stacking and Balancing', 'Stat Check Resolution', 'Static Capture', 'Stock Holding', 'Storytelling', 'Sudden Death Ending', 'Take That', 'Targeted Clues', 'Team-Based Game', 'Tech Trees / Tech Tracks', 'Three Dimensional Movement', 'Tile Placement', 'Time Track', 'Track Movement', 'Trading', 'Traitor Game', 'Trick-taking', 'Tug of War', 'Turn Order: Auction', 'Turn Order: Claim Action', 'Turn Order: Pass Order', 'Turn Order: Progressive', 'Turn Order: Random', 'Turn Order: Role Order', 'Turn Order: Stat-Based', 'Variable Phase Order', 'Variable Player Powers', 'Variable Set-up', 'Victory Points as a Resource', 'Voting', 'Worker Placement', 'Worker Placement with Dice Workers', 'Zone of Control']
# 202
# ['Abstract Games', "Children's Games", 'Customizable Games', 'Family Games', 'Party Games', 'Strategy Games', 'Thematic Games', 'Wargames']
# 8
# ['Acting', 'Action Drafting', 'Action Points', 'Action Queue', 'Action Retrieval', 'Action Timer', 'Action/Event', 'Advantage Token', 'Alliances', 'Area Majority / Influence', 'Area Movement', 'Area-Impulse', 'Auction/Bidding', 'Auction: Dexterity', 'Auction: Dutch', 'Auction: Dutch Priority', 'Auction: English', 'Auction: Fixed Placement', 'Auction: Once Around', 'Auction: Sealed Bid', 'Auction: Turn Order Until Pass', 'Automatic Resource Growth', 'Betting and Bluffing', 'Bias', 'Bingo', 'Bribery', 'Campaign / Battle Card Driven', 'Card Drafting', 'Card Play Conflict Resolution', 'Catch the Leader', 'Chaining', 'Chit-Pull System', 'Closed Economy Auction', 'Command Cards', 'Commodity Speculation', 'Communication Limits', 'Connections', 'Constrained Bidding', 'Contracts', 'Cooperative Game', 'Crayon Rail System', 'Critical Hits and Failures', 'Cube Tower', 'Deck Bag and Pool Building', 'Deck Construction', 'Deduction', 'Delayed Purchase', 'Dice Rolling', 'Die Icon Resolution', 'Different Dice Movement', 'Different Worker Types', 'Drafting', 'Elapsed Real Time Ending', 'Enclosure', 'End Game Bonuses', 'Events', 'Finale Ending', 'Flicking', 'Follow', 'Force Commitment', 'Grid Coverage', 'Grid Movement', 'Hand Management', 'Hexagon Grid', 'Hidden Movement', 'Hidden Roles', 'Hidden Victory Points', 'Highest-Lowest Scoring', 'Hot Potato', 'I Cut You Choose', 'Impulse Movement', 'Income', 'Increase Value of Unchosen Resources', 'Induction', 'Interrupts', 'Investment', 'Kill Steal', 'King of the Hill', 'Ladder Climbing', 'Layering', 'Legacy Game', 'Line Drawing', 'Line of Sight', 'Loans', 'Lose a Turn', 'Mancala', 'Map Addition', 'Map Deformation', 'Map Reduction', 'Market', 'Matching', 'Measurement Movement', 'Melding and Splaying', 'Memory', 'Minimap Resolution', 'Modular Board', 'Move Through Deck', 'Movement Points', 'Movement Template', 'Moving Multiple Units', 'Multiple Maps', 'Multiple-Lot Auction', 'Narrative Choice / Paragraph', 'Negotiation', 'Network and Route Building', 'Once-Per-Game Abilities', 'Order Counters', 'Ownership', 'Paper-and-Pencil', 'Passed Action Token', 'Pattern Building', 'Pattern Movement', 'Pattern Recognition', 'Physical Removal', 'Pick-up and Deliver', 'Pieces as Map', 'Player Elimination', 'Player Judge', 'Point to Point Movement', 'Predictive Bid', "Prisoner's Dilemma", 'Programmed Movement', 'Push Your Luck', 'Race', 'Random Production', 'Ratio / Combat Results Table', 'Re-rolling and Locking', 'Real-Time', 'Relative Movement', 'Resource to Move', 'Rock-Paper-Scissors', 'Role Playing', 'Roles with Asymmetric Information', 'Roll / Spin and Move', 'Rondel', 'Scenario / Mission / Campaign Game', 'Score-and-Reset Game', 'Secret Unit Deployment', 'Selection Order Bid', 'Semi-Cooperative Game', 'Set Collection', 'Simulation', 'Simultaneous Action Selection', 'Singing', 'Single Loser Game', 'Slide/Push', 'Solo / Solitaire Game', 'Speed Matching', 'Square Grid', 'Stacking and Balancing', 'Stat Check Resolution', 'Static Capture', 'Stock Holding', 'Storytelling', 'Sudden Death Ending', 'Take That', 'Targeted Clues', 'Team-Based Game', 'Tech Trees / Tech Tracks', 'Three Dimensional Movement', 'Tile Placement', 'Time Track', 'Track Movement', 'Trading', 'Traitor Game', 'Trick-taking', 'Tug of War', 'Turn Order: Auction', 'Turn Order: Claim Action', 'Turn Order: Pass Order', 'Turn Order: Progressive', 'Turn Order: Random', 'Turn Order: Role Order', 'Turn Order: Stat-Based', 'Variable Phase Order', 'Variable Player Powers', 'Variable Set-up', 'Victory Points as a Resource', 'Voting', 'Worker Placement', 'Worker Placement with Dice Workers', 'Zone of Control']
# 182

# %%
print('Domain Percentages')
half_mod = games['BGG Rank'].quantile(0.5).astype(int)

for domain in domains:
    total = (100*games[domain].sum()/len(games)).round(2)
    print('{}: {}'.format(domain, total))
print('\nMechanic Percentages')    
for mechanic in mechanics:
    total = (100*games[mechanic].sum()/len(games)).round(2)
    print('{}: {}'.format(mechanic, total))
# Out:
# Domain Percentages
# Abstract Games: 5.27
# Children's Games: 4.18
# Customizable Games: 1.46
# Family Games: 10.69
# Party Games: 2.98
# Strategy Games: 10.85
# Thematic Games: 5.78
# Wargames: 16.32
#
# Mechanic Percentages
# Acting: 1.13
# Action Drafting: 0.13
# Action Points: 5.32
# Action Queue: 1.95
# Action Retrieval: 0.25
# Action Timer: 0.07
# Action/Event: 0.12
# Advantage Token: 0.07
# Alliances: 0.17
# Area Majority / Influence: 7.39
# Area Movement: 5.52
# Area-Impulse: 0.51
# Auction/Bidding: 5.21
# Auction: Dexterity: 0.01
# Auction: Dutch: 0.05
# Auction: Dutch Priority: 0.01
# Auction: English: 0.0
# Auction: Fixed Placement: 0.04
# Auction: Once Around: 0.03
# Auction: Sealed Bid: 0.08
# Auction: Turn Order Until Pass: 0.07
# Automatic Resource Growth: 0.06
# Betting and Bluffing: 1.98
# Bias: 0.2
# Bingo: 0.15
# Bribery: 0.08
# Campaign / Battle Card Driven: 2.66
# Card Drafting: 8.51
# Card Play Conflict Resolution: 0.28
# Catch the Leader: 0.15
# Chaining: 0.08
# Chit-Pull System: 1.23
# Closed Economy Auction: 0.04
# Command Cards: 0.09
# Commodity Speculation: 1.22
# Communication Limits: 0.47
# Connections: 0.18
# Constrained Bidding: 0.09
# Contracts: 0.4
# Cooperative Game: 6.9
# Crayon Rail System: 0.11
# Critical Hits and Failures: 0.21
# Cube Tower: 0.07
# Deck Bag and Pool Building: 3.52
# Deck Construction: 0.11
# Deduction: 0.23
# Delayed Purchase: 0.05
# Dice Rolling: 27.91
# Die Icon Resolution: 0.13
# Different Dice Movement: 0.03
# Different Worker Types: 0.26
# Drafting: 0.53
# Elapsed Real Time Ending: 0.07
# Enclosure: 0.98
# End Game Bonuses: 0.58
# Events: 1.19
# Finale Ending: 0.05
# Flicking: 0.22
# Follow: 0.17
# Force Commitment: 0.06
# Grid Coverage: 0.19
# Grid Movement: 7.27
# Hand Management: 20.42
# Hexagon Grid: 11.08
# Hidden Movement: 0.35
# Hidden Roles: 0.32
# Hidden Victory Points: 0.12
# Highest-Lowest Scoring: 0.09
# Hot Potato: 0.03
# I Cut You Choose: 0.13
# Impulse Movement: 0.04
# Income: 0.35
# Increase Value of Unchosen Resources: 0.17
# Induction: 0.03
# Interrupts: 0.09
# Investment: 0.13
# Kill Steal: 0.07
# King of the Hill: 0.07
# Ladder Climbing: 0.19
# Layering: 0.1
# Legacy Game: 0.11
# Line Drawing: 0.69
# Line of Sight: 1.05
# Loans: 0.1
# Lose a Turn: 0.1
# Mancala: 0.16
# Map Addition: 0.16
# Map Deformation: 0.07
# Map Reduction: 0.12
# Market: 0.25
# Matching: 0.05
# Measurement Movement: 0.41
# Melding and Splaying: 0.11
# Memory: 4.41
# Minimap Resolution: 0.13
# Modular Board: 7.99
# Move Through Deck: 0.11
# Movement Points: 2.08
# Movement Template: 0.12
# Moving Multiple Units: 0.06
# Multiple Maps: 0.09
# Multiple-Lot Auction: 0.04
# Narrative Choice / Paragraph: 0.14
# Negotiation: 0.19
# Network and Route Building: 2.65
# Once-Per-Game Abilities: 0.15
# Order Counters: 0.02
# Ownership: 0.18
# Paper-and-Pencil: 2.35
# Passed Action Token: 0.02
# Pattern Building: 3.75
# Pattern Movement: 0.04
# Pattern Recognition: 2.55
# Physical Removal: 0.05
# Pick-up and Deliver: 2.8
# Pieces as Map: 0.05
# Player Elimination: 3.29
# Player Judge: 0.1
# Point to Point Movement: 4.31
# Predictive Bid: 0.03
# Prisoner's Dilemma: 0.06
# Programmed Movement: 0.15
# Push Your Luck: 4.16
# Race: 0.67
# Random Production: 0.06
# Ratio / Combat Results Table: 1.28
# Re-rolling and Locking: 0.2
# Real-Time: 0.33
# Relative Movement: 0.05
# Resource to Move: 0.1
# Rock-Paper-Scissors: 0.82
# Role Playing: 2.5
# Roles with Asymmetric Information: 0.13
# Roll / Spin and Move: 6.41
# Rondel: 0.26
# Scenario / Mission / Campaign Game: 2.06
# Score-and-Reset Game: 0.08
# Secret Unit Deployment: 2.77
# Selection Order Bid: 0.01
# Semi-Cooperative Game: 0.19
# Set Collection: 13.44
# Simulation: 9.56
# Simultaneous Action Selection: 5.41
# Singing: 0.24
# Single Loser Game: 0.08
# Slide/Push: 0.07
# Solo / Solitaire Game: 3.3
# Speed Matching: 0.07
# Square Grid: 0.91
# Stacking and Balancing: 0.21
# Stat Check Resolution: 0.12
# Static Capture: 0.12
# Stock Holding: 1.44
# Storytelling: 2.23
# Sudden Death Ending: 0.15
# Take That: 4.84
# Targeted Clues: 0.09
# Team-Based Game: 4.69
# Tech Trees / Tech Tracks: 0.2
# Three Dimensional Movement: 0.24
# Tile Placement: 8.33
# Time Track: 0.6
# Track Movement: 0.28
# Trading: 2.95
# Traitor Game: 0.35
# Trick-taking: 1.79
# Tug of War: 0.09
# Turn Order: Auction: 0.06
# Turn Order: Claim Action: 0.16
# Turn Order: Pass Order: 0.07
# Turn Order: Progressive: 0.28
# Turn Order: Random: 0.04
# Turn Order: Role Order: 0.05
# Turn Order: Stat-Based: 0.16
# Variable Phase Order: 1.46
# Variable Player Powers: 12.47
# Variable Set-up: 1.14
# Victory Points as a Resource: 0.26
# Voting: 2.14
# Worker Placement: 3.69
# Worker Placement with Dice Workers: 0.25
# Zone of Control: 1.12

# %%
print(games['BGG Rank'].quantile([0.01, 0.1, 0.5]))
# Out:
# 0.01      204.19
# 0.10     2032.90
# 0.50    10168.50
# Name: BGG Rank, dtype: float64

# %%
#Ok, the variables are silly, yes.  But to be fair, it's bed time and I didn't think this would work.
blah = games['Owned Users'].min()
blah = blah.astype(int)
bloo = games['Owned Users'].max()
bloo = bloo.astype(int)
print(type(blah))

#Now that I have my working inputs, let's get the sets ready for my log plot.
owners_x = range(blah, bloo, 1)
owners_y = []
for x in owners_x:
    y = len(games[games['Owned Users']==x])
    owners_y.append(y)
# Out:
# <class 'numpy.int32'>

# %%
ax1 = plt.gca()
plt.scatter(owners_x, owners_y)
ax1.set_yscale('log')
ax1.set_xscale('log')
plt.savefig('log experiement game ownership.png')
plt.show()
